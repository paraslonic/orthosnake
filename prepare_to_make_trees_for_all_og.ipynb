# %%
ls Results/Orthofinder_results/Orthogroup_Sequences/ | sed 's/.fa//' > tmp/all_og_list

# %%
# тут ортогруппы с больше чем 1 сиквенсом
awk '{print $1}' Results/Orthofinder_results/Orthogroups/Orthogroups.GeneCount.tsv | tail
# Out:
# OG0014539
# OG0014540
# OG0014541
# OG0014542
# OG0014543
# OG0014544
# OG0014545
# OG0014546
# OG0014547
# OG0014548

# %%
# R

# %%
genecount = read.delim("Results/Orthofinder_results/Orthogroups/Orthogroups.GeneCount.tsv")

# %%
rownames(genecount) = genecount$Orthogroup
genecount = genecount[,-1]

# %%
genecount = genecount[,-ncol(genecount)]

# %%
genecount[genecount > 0] = 1

# %%
head(genecount)
# Out:
#           GCF_000010385.1_ASM1038v1_genomic GCF_000017745.1_ASM1774v1_genomic
# OG0000000 1                                 1
# OG0000001 1                                 1
# OG0000002 1                                 1
# OG0000003 1                                 1
# OG0000004 1                                 1
# OG0000005 1                                 1
#           GCF_000017765.1_ASM1776v1_genomic GCF_000027125.1_ASM2712v1_genomic
# OG0000000 1                                 1
# OG0000001 1                                 1
# OG0000002 1                                 0
# OG0000003 1                                 1
# OG0000004 1                                 1
# OG0000005 1                                 1
#           GCF_000167875.2_ASM16787v2_genomic GCF_000212715.2_ASM21271v2_genomic
# OG0000000 1                                  1
# OG0000001 1                                  1
# OG0000002 1                                  1
# ...

# %%
rowSums(genecount)
# Out:
# OG0000000 OG0000001 OG0000002 OG0000003 OG0000004 OG0000005 OG0000006 OG0000007
#     16212      8536      7302      6418      5946      4986      4782      4536
# OG0000008 OG0000009 OG0000010 OG0000011 OG0000012 OG0000013 OG0000014 OG0000015
#      4486      4236      3974      3926      3780      3776      3762      3646
# OG0000016 OG0000017 OG0000018 OG0000019 OG0000020 OG0000021 OG0000022 OG0000023
#      3340      3304      3282      3238      3220      3094      3030      3014
# OG0000024 OG0000025 OG0000026 OG0000027 OG0000028 OG0000029 OG0000030 OG0000031
#      2986      2978      2966      2902      2868      2846      2842      2662
# OG0000032 OG0000033 OG0000034 OG0000035 OG0000036 OG0000037 OG0000038 OG0000039
#      2658      2632      2604      2580      2574      2524      2484      2446
# OG0000040 OG0000041 OG0000042 OG0000043 OG0000044 OG0000045 OG0000046 OG0000047
#      2366      2354      2326      2318      2314      2314      2306      2286
# ...

# %%
wc -l tmp/all_og_list
# Out:
# 19697 tmp/all_og_list

# %%
grep ">" Results/Orthofinder_results/Orthogroup_Sequences/OG0014548.fa
# Out:
# >GCF_905071835.1_MSB1_4I_genomic|5097|hypothetical_protein|NZ_LR898875.1|16413|16584
# >GCF_905071835.1_MSB1_4I_genomic|5303|hypothetical_protein|NZ_LR898878.1|3850|4021

# %%
ll -h tmp/all_genes_nuc.fasta
# Out:
# -rwxrwxrwx 1 manolov biodata 2.4G May  1 18:44 tmp/all_genes_nuc.fasta*

# %%
mkdir -p Results/ortho/allogs_nuc

# %%
head Results/Orthogroups_SingleCopyOrthologues.txt
# Out:
# OG0001295
# OG0001296
# OG0001297
# OG0001298
# OG0001299
# OG0001300
# OG0001301
# OG0001302
# OG0001303
# OG0001304

# %%
perl scripts/splitToOg.pl Results/Orthogroups.txt tmp/all_genes_nuc.fasta Results/ortho/allogs_nuc Results/Orthogroups_SingleCopyOrthologues.txt
